# %%
import pygidfit
filename = r'..\tests\240305_PEN_DIP_0001_all.h5'
filename = r'..\tests\240305_PEN_DIP_0001_10_after_gui.h5'
# filename = r'..\tests\240305_PEN_DIP_0001_10.h5'
pygidfit.run_scans(filename,
          polar_shape = [512*2,1024*2],
          batch_size = 20,
          crit_angle = 0.1,
          debag = False,
          multiprocessing = False)
# Out:
# image fitting took 798.8629341125488 ms

# %%
import pygidfit
filename = r'..\tests\240305_PEN_DIP_0001_all.h5'
filename = r'..\tests\240305_PEN_DIP_0001_10_after_gui.h5'
filename = r'..\tests\240305_PEN_DIP_0001_10.h5'
pygidfit.run_scans(filename,
          polar_shape = [512*2,1024*2],
          batch_size = 20,
          crit_angle = 0.1,
          debag = False,
          multiprocessing = False)
# Out:
# image fitting took 1355.377197265625 ms
