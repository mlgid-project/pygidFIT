# %%
import pygidfit
filename = r'D:\PhD\Programs\WPy64-31241\notebooks\mlgid_packages\BA2PbI4.h5'
# filename = r'D:\PhD\pygidFIT\tests\240305_PEN_DIP_0001_all.h5'
# filename = r'\\moneta.uni-tuebingen.de\groupshare\OMBD\Ainur\new_format.h5'
# filename = r'D:\PhD\pygidFIT\tests\240305_PEN_DIP_0001_10_after_gui.h5'
# filename = r'..\tests\240305_PEN_DIP_0001_10.h5'
pygidfit.run_scans(filename,
          polar_shape = [512*2,1024*2],
          batch_size = 1,
          crit_angle = 1,
          use_pool = True,
          debug = False,
          multiprocessing = False)
# Out:
# image fitting took 4808.205366134644 ms

# %%
import pygidfit

import pickle, time
import numpy as np
with open(r"D:\PhD\Programs\WPy64-31241\notebooks\mlgid_packages\img_container.pkl", "rb") as f:
    img_container = pickle.load(f)


# filename = r'D:\PhD\pygidFIT\tests\240305_PEN_DIP_0001_all.h5'
# filename = r'\\moneta.uni-tuebingen.de\groupshare\OMBD\Ainur\new_format.h5'
# filename = r'D:\PhD\pygidFIT\tests\240305_PEN_DIP_0001_10_after_gui.h5'
# filename = r'..\tests\240305_PEN_DIP_0001_10.h5'
pygidfit.run_scans_img_container(img_container,
          polar_shape = None,
          batch_size = 1,
          crit_angle = 1,
          use_pool = True,
          debug = False,
          multiprocessing = False)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 6
#       4 import numpy as np
#       5 with open(r"D:\PhD\Programs\WPy64-31241\notebooks\mlgid_packages\img_container.pkl", "rb") as f:
# ----> 6     img_container = pickle.load(f)
#       9 # filename = r'D:\PhD\pygidFIT\tests\240305_PEN_DIP_0001_all.h5'
#      10 # filename = r'\\moneta.uni-tuebingen.de\groupshare\OMBD\Ainur\new_format.h5'
#      11 # filename = r'D:\PhD\pygidFIT\tests\240305_PEN_DIP_0001_10_after_gui.h5'
#      12 # filename = r'..\tests\240305_PEN_DIP_0001_10.h5'
#      13 pygidfit.run_scans_img_container(img_container,
#      14           polar_shape = None,
#      15           batch_size = 1,
#    (...)     18           debug = False,
#      19           multiprocessing = False)
#
# ModuleNotFoundError: No module named 'mlgiddetect'

# %%
from pygidfit.main import run_scans
run_scans(filename,
          polar_shape = [512*2,1024*2],
          batch_size = 20,
          crit_angle = 0.1,
          debug = False,
          multiprocessing = False)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 2
#       1 from pygidfit.main import run_scans
# ----> 2 run_scans(filename,
#       3           polar_shape = [512*2,1024*2],
#       4           batch_size = 20,
#       5           crit_angle = 0.1,
#       6           debug = False,
#       7           multiprocessing = False)
#
# File D:\PhD\mlgid\pygidFIT\pygidfit\main.py:26, in run_scans(filename, batch_size, crit_angle, polar_shape, debug, multiprocessing)
#       8 def run_scans(
#       9         filename = None,
#      10         batch_size = 10,
#    (...)     14         multiprocessing = True,
#      15     ):
#      16     """
#      17     Main function to process a range of scans.
#      18
#    (...)     23         n_jobs: Number of parallel jobs to use (-1 for all cores)
#      24     """
# ---> 26     process_data_from_file(
# ...

# %%
image fitting took 108032.32169151306 ms
image fitting took 113816.86162948608 ms
image fitting took 127067.72136688232 ms
image fitting took 105597.57709503174 ms
image fitting took 87012.54343986511 ms
image fitting took 67308.75658988953 ms
image fitting took 45589.5562171936 ms
image fitting took 59413.16866874695 ms
image fitting took 64095.74246406555 ms
image fitting took 52144.05274391174 ms
image fitting took 44753.47447395325 ms
